# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_excel('/content/drive/MyDrive/Estatistica/AirQualityUCI.xlsx')

# %%
df = df.drop('PT08.S1(CO)', axis = 1)
df = df.drop('NMHC(GT)', axis = 1)
df = df.drop('C6H6(GT)', axis = 1)
df = df.drop('PT08.S2(NMHC)', axis = 1)
df = df.drop('PT08.S3(NOx)', axis = 1)
df = df.drop('PT08.S4(NO2)', axis = 1)
df = df.drop('PT08.S5(O3)', axis = 1)
df.head()

# %%
df = df.replace(-200, np.nan)
df = df.dropna()
df.loc[184]
# Out:
# Date       2004-03-18 00:00:00
# Time                  10:00:00
# CO(GT)                     4.5
# NOx(GT)                  349.0
# NO2(GT)                  150.0
# T                        17.85
# RH                      40.525
# AH                    0.820964
# Name: 184, dtype: object

# %%
df.head()
df.to_excel('dados_processados.xlsx', index=False)

# %%
plt.scatter(df["NO2(GT)"], df["T"])
plt.show()

# %%
plt.scatter(df["T"], df["NO2(GT)"])
plt.show()

# %%
plt.plot(df["T"], df["NO2(GT)"], marker='o', linestyle='-')
plt.xlabel('Eixo T')
plt.ylabel('Eixo NO2')

# Adicione um título ao gráfico
plt.title('T x No2')

# Exiba o gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5ce4bbd1bfff> in <cell line: 1>()
# ----> 1 plt.plot(df["T"], df["NO2(GT)"], marker='o', linestyle='-')
#       2 plt.xlabel('Eixo T')
#       3 plt.ylabel('Eixo NO2')
#       4
#       5 # Adicione um título ao gráfico
#
# NameError: name 'plt' is not defined
